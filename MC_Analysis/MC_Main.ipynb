# %% [markdown]
# #### Monte Carlo Analysis

# %%
from IPython.display import Image
Image(filename = '/Users/mburley/Downloads/GBM_MC.png', width = 500, height = 200)

# %%
### Function Calls and Outputs

from MC_Functions import import_stock_data, log_returns, drift_calc, daily_returns, simulate_mc, monte_carlo

start = "2010-1-1"
days_to_forecast = 252
simulation_trials = 10000
tickers = ['GOOG', 'AAPL', 'AMZN']

#data = import_stock_data('GOOG', start)
#print(data)

#log_rets = log_returns(data)
#print(log_rets)

#drift = drift_calc(data)
#print(drift)

#daily_rets = daily_returns(data, days_to_forecast, simulation_trials)
#print(daily_rets)

#sim = simulate_mc(data, 252, 1000, 'log')
#print(sim)

ret_sim_df = monte_carlo(tickers, days_forecast = days_to_forecast, iterations = simulation_trials,  start_date = start)
print(ret_sim_df)
# Out:
# [*********************100%%**********************]  3 of 3 completed
# [*********************100%%**********************]  1 of 1 completed
# /Users/mburley/matthew_git/Stock_Project/Monte_Carlo_Analysis/MC_Functions.py:173: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, ax=ax[0])
# /Users/mburley/matthew_git/Stock_Project/Monte_Carlo_Analysis/MC_Functions.py:174: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...
